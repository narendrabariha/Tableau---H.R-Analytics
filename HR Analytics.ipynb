# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import os 
import warnings 

warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\Hp\Downloads\HR Data.xlsx")

# %%
df.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
df.tail()
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number Gender  \
# 1465  Technical Degree  STAFF-1905             1905   Male
# 1466     Life Sciences  STAFF-1868             1868   Male
# 1467             Other  STAFF-1667             1667   Male
# 1468     Life Sciences  STAFF-1878             1878   Male
# 1469     Life Sciences  STAFF-1702             1702   Male
#
#                   Job Role  ... Performance Rating Relationship Satisfaction  \
# ...

# %%
df.shape
# Out:
# (1470, 39)

# %%
data=df

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
data.describe()
# Out:
#        Employee Number  Training Times Last Year          Age  \
# count      1470.000000               1470.000000  1470.000000
# mean       1024.865306                  2.799320    36.923810
# std         602.024335                  1.289271     9.135373
# min           1.000000                  0.000000    18.000000
# 25%         491.250000                  2.000000    30.000000
# 50%        1020.500000                  3.000000    36.000000
# 75%        1555.750000                  3.000000    43.000000
# max        2068.000000                  6.000000    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# std               0.367863   403.509100            8.106864             0.0
# min               0.000000   102.000000            1.000000             1.0
# ...

# %%
missing_values = data.isnull().sum()  # Count missing values per column
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# ...

# %%
duplicates = data.duplicated().sum()  # Count duplicate rows
print("\nNumber of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(x='Attrition', data=data, )
plt.title('Attrition Count')
plt.xlabel('Attrition')
plt.ylabel('Count')

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Department', hue='Attrition', data=data, palette='viridis')
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Work Life Balance', y='Job Satisfaction', hue='Attrition', data=data, palette='husl', ci=None)
plt.title('Work-Life Balance vs Job Satisfaction')
plt.xlabel('Work Life Balance')
plt.ylabel('Job Satisfaction')

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
# Plot 4: Attrition by Gender and Overtime (Grouped Bar Plot)
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Gender', hue='Over Time', data=data)
plt.title('Attrition by Gender and Overtime')
plt.xlabel('Gender')
plt.ylabel('Count')

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# Plot 5: Distribution of Total Working Years (Histogram)
plt.figure(figsize=(8, 5))
sns.histplot(data['Total Working Years'], kde=True, bins=20, color='purple')
plt.title('Total Working Years Distribution')
plt.xlabel('Total Working Years')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='Age', hue='Attrition', data=data)
plt.title('Attrition by Education Field')
plt.xlabel('Age ')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
a=sns.countplot(data=data, x="Education Field") 
fig= plt.gcf()
fig.set_size_inches(10,5) 
plt.title('Education Field')
for bars in a.containers:
    a.bar_label(bars)

plt.show()

# %%
a = sns.countplot(x='Job Role', data=df)
fig = plt.gcf()
fig.set_size_inches(21, 5)
plt.title('Job Role')

# Adding bar labels
for bars in a.containers:
    a.bar_label(bars)

plt.show()

# %%
# Plot 6: Attrition by Education Field (Bar Plot)
plt.figure(figsize=(10, 5))
ax = sns.countplot(x='Education Field', hue='Attrition', data=data, palette='Set3')
plt.title('Attrition by Education Field')
plt.xlabel('Education Field')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# Plot 7: Attrition by Job Role (Bar Plot)
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Job Role', hue='Attrition', data=data, palette='Set2')
plt.title('Attrition by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
# Distribution of Performance Rating
plt.figure(figsize=(8, 5))
ax=sns.countplot(data=data, x='Performance Rating', palette='viridis')
plt.title('Performance Rating Distribution')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
# Heatmap for features most correlated with Performance Rating
selected_features = performance_corr[abs(performance_corr) > 0.3].index
plt.figure(figsize=(10, 6))
sns.heatmap(data[selected_features].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap (Selected Features)')
plt.show()

# %%
# Plot 8: Monthly Income vs. Job Satisfaction (Scatter Plot with Regression Line)
plt.figure(figsize=(8, 5))
sns.regplot(x='Monthly Income', y='Job Satisfaction', data=data, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Monthly Income vs Job Satisfaction')
plt.xlabel('Monthly Income')
plt.ylabel('Job Satisfaction')
plt.show()

# Plot 9: Years at Company vs. Total Working Years (Scatter Plot with Hue)
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Years At Company', y='Total Working Years', hue='Attrition', data=data, palette='coolwarm')
plt.title('Years at Company vs Total Working Years')
plt.xlabel('Years at Company')
plt.ylabel('Total Working Years')
plt.show()

# %%
# Plot 10: Attrition by Work-Life Balance (Stacked Bar Plot)
plt.figure(figsize=(8, 5))
work_life_attrition = data.groupby(['Work Life Balance', 'Attrition']).size().unstack()
work_life_attrition.plot(kind='bar', stacked=True, colormap='viridis', figsize=(8, 5))
plt.title('Attrition by Work-Life Balance')
plt.xlabel('Work-Life Balance')
plt.ylabel('Count')
plt.legend(title='Attrition')
plt.show()

# Plot 11: Box Plot - Years Since Last Promotion vs. Attrition
plt.figure(figsize=(8, 5))
sns.boxplot(x='Attrition', y='Years Since Last Promotion', data=data, palette='Set1')
plt.title('Years Since Last Promotion by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Years Since Last Promotion')
plt.show()

# %%
# Plot 12: Violin Plot - Distance from Home vs. Attrition
plt.figure(figsize=(8, 5))
sns.violinplot(x='Attrition', y='Distance From Home', data=data, palette='muted')
plt.title('Distance From Home by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Distance From Home')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Convert categorical columns to numeric if needed
data_encoded = data.copy()

# Map categorical values (example: for 'Attrition')
if 'Attrition' in data.columns:
    data_encoded['Attrition'] = data['Attrition'].map({'Yes': 1, 'No': 0})

# Select only numeric columns
numeric_data = data_encoded.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
corr_matrix = numeric_data.corr()

# Plot the heatmap
plt.figure(figsize=(20, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot 14: Attrition by Monthly Income and Age (Bubble Plot)
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='Age', y='Monthly Income', size='Years At Company', hue='Attrition', data=data,
    sizes=(20, 300), alpha=0.6, palette='viridis'
)
plt.title('Attrition by Monthly Income and Age')
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.legend(title='Attrition')
plt.show()

# Plot 15: Job Satisfaction vs. Environment Satisfaction (Facet Grid by Attrition)
g = sns.FacetGrid(data, col='Attrition', height=5, aspect=1.2)
g.map_dataframe(sns.scatterplot, x='Job Satisfaction', y='Environment Satisfaction', color='blue')
g.set_axis_labels("Job Satisfaction", "Environment Satisfaction")
g.set_titles("Attrition = {col_name}")
g.fig.suptitle('Job vs Environment Satisfaction by Attrition', y=1.03)
plt.show()

# %%
# Plot 16: Distribution of Age by Attrition (Box Plot)
plt.figure(figsize=(8, 5))
sns.boxplot(x='Attrition', y='Age', data=data, palette='cool')
plt.title('Distribution of Age by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Age')
plt.show()

# Plot 17: Attrition by Years with Current Manager (KDE Plot)
plt.figure(figsize=(8, 5))
sns.kdeplot(data[data['Attrition'] == 'Yes']['Years With Curr Manager'], label='Attrition = Yes', shade=True, color='red')
sns.kdeplot(data[data['Attrition'] == 'No']['Years With Curr Manager'], label='Attrition = No', shade=True, color='blue')
plt.title('Years with Current Manager by Attrition')
plt.xlabel('Years with Current Manager')
plt.legend()
plt.show()

# %%
# Plot 18: Attrition by Percent Salary Hike (Boxen Plot)
plt.figure(figsize=(8, 5))
sns.boxenplot(x='Attrition', y='Percent Salary Hike', data=data, palette='muted')
plt.title('Attrition by Percent Salary Hike')
plt.xlabel('Attrition')
plt.ylabel('Percent Salary Hike')
plt.show()

# Plot 19: Categorical Comparison - Business Travel and Job Role
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='Business Travel', hue='Job Role', data=data, palette='Spectral')
plt.title('Business Travel by Job Role')
plt.xlabel('Business Travel')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add bar labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
# Plot 20: Attrition and Work-Life Balance by Gender (Heatmap)
pivot_table = pd.crosstab(data['Gender'], [data['Attrition'], data['Work Life Balance']])
plt.figure(figsize=(8, 5))
sns.heatmap(pivot_table, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Attrition and Work-Life Balance by Gender')
plt.xlabel('Attrition and Work-Life Balance')
plt.ylabel('Gender')
plt.show()

# Plot 21: Pair Plot for Key Features
key_features = ['Age', 'Monthly Income', 'Total Working Years', 'Years At Company', 'Attrition']
sns.pairplot(data[key_features], hue='Attrition', palette='coolwarm', diag_kind='kde')
plt.suptitle('Pair Plot of Key Features', y=1.02)
plt.show()

# %%
# Plot 22: Attrition by Training Times Last Year (Swarm Plot)
plt.figure(figsize=(8, 5))
sns.swarmplot(x='Attrition', y='Training Times Last Year', data=data, palette='Set2')
plt.title('Attrition by Training Times Last Year')
plt.xlabel('Attrition')
plt.ylabel('Training Times Last Year')
plt.show()

# %%
plt.figure(figsize=(12, 6))
attrition_dept_role = pd.crosstab(data['Department'], data['Job Role'], normalize='index') * 100
attrition_dept_role.plot(kind='bar', stacked=True, colormap='viridis', figsize=(12, 6))
plt.title('Attrition by Department and Job Role (Normalized)')
plt.xlabel('Department')
plt.ylabel('Percentage')
plt.legend(title='Job Role', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Attrition', y='Years Since Last Promotion', data=data, palette='cool')
plt.title('Attrition by Years Since Last Promotion')
plt.xlabel('Attrition')
plt.ylabel('Years Since Last Promotion')
plt.show()

# %%
attrition_env = data.groupby(['Attrition', 'Environment Satisfaction']).size().unstack()
attrition_env.T.plot(kind='pie', subplots=True, figsize=(15, 5), autopct='%1.1f%%', legend=False)
plt.suptitle('Environment Satisfaction Distribution by Attrition')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Job Level', y='Monthly Income', hue='Gender', data=data, palette='Set2')
plt.title('Monthly Income by Gender and Job Level')
plt.xlabel('Job Level')
plt.ylabel('Monthly Income')
plt.legend(title='Gender')
plt.show()

# %%
age_band_attrition = data.groupby(['CF_age band', 'Attrition']).size().unstack()
age_band_attrition = (age_band_attrition.div(age_band_attrition.sum(axis=1), axis=0) * 100).reset_index()
age_band_attrition.plot(x='CF_age band', kind='bar', stacked=True, figsize=(10, 6), colormap='cividis')
plt.title('Attrition Rate by Age Band')
plt.xlabel('Age Band')
plt.ylabel('Percentage')
plt.legend(title='Attrition')
plt.show()

# %%
plt.figure(figsize=(16, 6))
pivot_table = pd.crosstab(
    data['Work Life Balance'], 
    data['Job Satisfaction'], 
    values=data['Attrition'].map({'Yes': 1, 'No': 0}), 
    aggfunc='mean'
)
sns.heatmap(pivot_table, annot=True, cmap='Blues', fmt='.2f', linewidths=0.5)
plt.title('Attrition by Work-Life Balance and Job Satisfaction')
plt.xlabel('Job Satisfaction')
plt.ylabel('Work Life Balance')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='Total Working Years', 
    y='Years At Company', 
    hue='Attrition', 
    size='Age', 
    data=data, 
    alpha=0.7, 
    palette='coolwarm', 
    sizes=(50, 200)
)
plt.title('Years at Company vs. Total Working Years by Attrition')
plt.xlabel('Total Working Years')
plt.ylabel('Years At Company')
plt.legend(title='Attrition')
plt.show()

# %%
attrition_edu = data[data['Attrition'] == 'Yes']['Education Field'].value_counts()
plt.figure(figsize=(8, 7))
plt.pie(attrition_edu, labels=attrition_edu.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
plt.title('Attrition Distribution by Education Field')
plt.show()
